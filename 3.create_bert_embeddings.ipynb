# %% [markdown]
# ## 1. Import Libraries and Setup

# %%
import json
import numpy as np
import requests
from tqdm.auto import tqdm
from datetime import datetime
import time
import os
from pathlib import Path

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ## 2. Configuration

# %%
# API Configuration
BERT_API_URL = "http://127.0.0.1:8001/embed"
BERT_INFO_URL = "http://127.0.0.1:8001/"

# File paths
INPUT_FILE = "cleaned_dataset.json"
OUTPUT_EMBEDDINGS = "bert_embeddings.npy"
OUTPUT_METADATA = "bert_embeddings_metadata.json"
CHECKPOINT_DIR = "bert_checkpoints"

# Processing parameters
BATCH_SIZE = 1  # Number of texts to embed per API call
MAX_RETRIES = 3  # Number of retries for failed API calls
RETRY_DELAY = 2  # Seconds to wait before retrying
CHECKPOINT_INTERVAL = 500  # Save checkpoint every N papers

# Embedding parameters
NORMALIZE = True  # Normalize embeddings to unit vectors
MAX_LENGTH = 8192  # Maximum sequence length (BioClinical ModernBERT supports long contexts)

# Create checkpoint directory
Path(CHECKPOINT_DIR).mkdir(exist_ok=True)

print("✓ Configuration set")
print(f"  - API URL: {BERT_API_URL}")
print(f"  - Batch size: {BATCH_SIZE}")
print(f"  - Max sequence length: {MAX_LENGTH}")
print(f"  - Checkpoint interval: {CHECKPOINT_INTERVAL}")
# Out:
# ✓ Configuration set
#   - API URL: http://127.0.0.1:8001/embed
#   - Batch size: 1
#   - Max sequence length: 8192
#   - Checkpoint interval: 500

# %% [markdown]
# ## 3. Test API Connection

# %%
# Test connection to BERT API
try:
    response = requests.get(BERT_INFO_URL, timeout=5)
    response.raise_for_status()
    info = response.json()
    
    print("✓ Successfully connected to BERT API")
    print(f"  - Service: {info.get('service', 'N/A')}")
    print(f"  - Model: {info.get('model', 'N/A')}")
    print(f"  - Device: {info.get('device', 'N/A')}")
    print(f"  - Embedding dimension: {info.get('embedding_dim', 'N/A')}")
    print(f"  - Max length: {info.get('default_max_length', 'N/A')}")
    
    EMBEDDING_DIM = info.get('embedding_dim', 1024)
    
except requests.exceptions.RequestException as e:
    print(f"✗ Failed to connect to BERT API: {e}")
    print("  Please ensure the BERT API server is running on http://127.0.0.1:8001")
    raise
# Out:
# ✓ Successfully connected to BERT API
#   - Service: bioclinical-modernbert-api
#   - Model: thomas-sounack/BioClinical-ModernBERT-large
#   - Device: cuda
#   - Embedding dimension: 1024
#   - Max length: 8192

# %% [markdown]
# ## 4. Load Dataset

# %%
# Load the cleaned dataset
print(f"Loading dataset from {INPUT_FILE}...")
start_time = time.time()

with open(INPUT_FILE, 'r', encoding='utf-8') as f:
    dataset = json.load(f)

load_time = time.time() - start_time

print(f"✓ Dataset loaded in {load_time:.2f} seconds")
print(f"  - Total papers: {len(dataset):,}")
print(f"  - File size: {os.path.getsize(INPUT_FILE) / (1024**2):.2f} MB")

# Check data structure
if dataset:
    sample = dataset[0]
    print(f"\nSample paper keys: {list(sample.keys())}")
    
    if 'full_text' in sample:
        print(f"✓ 'full_text' field found")
        print(f"  - Sample text length: {len(sample['full_text'])} characters")
        print(f"  - Sample text preview: {sample['full_text'][:200]}...")
    else:
        print("✗ 'full_text' field not found in dataset!")
        raise ValueError("Dataset must contain 'full_text' field")
# Out:
# Loading dataset from cleaned_dataset.json...
# ✓ Dataset loaded in 1.23 seconds
#   - Total papers: 67,043
#   - File size: 332.53 MB
#
# Sample paper keys: ['id', 'title', 'abstract', 'authors', 'journal', 'publication_year', 'publication_month', 'publication_day', 'doi', 'keywords', 'mesh', 'language_list', 'embedding', 'full_text', 'cleaned_text']
# ✓ 'full_text' field found
#   - Sample text length: 1538 characters
#   - Sample text preview: Immunomodulation by cytokine antisense oligonucleotides. The cytokine network is involved in normal immune reaction and in the progression of several pathologies. Antisense (AS) oligonucleotides, whic...

# %% [markdown]
# ## 5. Define Embedding Functions

# %%
def embed_batch(texts, normalize=True, max_length=None, max_retries=MAX_RETRIES):
    """
    Embed a batch of texts using the BERT API.
    
    Args:
        texts: List of text strings to embed
        normalize: Whether to normalize embeddings
        max_length: Maximum sequence length
        max_retries: Maximum number of retry attempts
        
    Returns:
        numpy array of embeddings, shape (len(texts), embedding_dim)
    """
    payload = {
        "texts": texts,
        "normalize": normalize,
        "max_length": max_length
    }
    
    for attempt in range(max_retries):
        try:
            response = requests.post(BERT_API_URL, json=payload, timeout=120)
            response.raise_for_status()
            
            result = response.json()
            embeddings = np.array(result['embeddings'], dtype=np.float32)
            
            return embeddings
            
        except requests.exceptions.RequestException as e:
            if attempt < max_retries - 1:
                print(f"  ⚠ Attempt {attempt + 1} failed: {e}. Retrying in {RETRY_DELAY}s...")
                time.sleep(RETRY_DELAY)
            else:
                print(f"  ✗ All {max_retries} attempts failed for batch")
                raise
    
    return None


def save_checkpoint(embeddings_list, current_idx, checkpoint_dir=CHECKPOINT_DIR):
    """
    Save a checkpoint of the current progress.
    
    Args:
        embeddings_list: List of embedding arrays
        current_idx: Current index in the dataset
        checkpoint_dir: Directory to save checkpoints
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    checkpoint_file = os.path.join(checkpoint_dir, f"checkpoint_{current_idx}_{timestamp}.npy")
    
    embeddings_array = np.vstack(embeddings_list)
    np.save(checkpoint_file, embeddings_array)
    
    print(f"  💾 Checkpoint saved: {checkpoint_file} (shape: {embeddings_array.shape})")
    
    return checkpoint_file


def load_latest_checkpoint(checkpoint_dir=CHECKPOINT_DIR):
    """
    Load the latest checkpoint if it exists.
    
    Returns:
        (embeddings_array, start_idx) or (None, 0) if no checkpoint found
    """
    checkpoint_files = list(Path(checkpoint_dir).glob("checkpoint_*.npy"))
    
    if not checkpoint_files:
        return None, 0
    
    # Get the latest checkpoint
    latest_checkpoint = max(checkpoint_files, key=lambda p: p.stat().st_mtime)
    
    # Extract index from filename
    filename = latest_checkpoint.stem
    start_idx = int(filename.split('_')[1])
    
    # Load embeddings
    embeddings = np.load(latest_checkpoint)
    
    print(f"✓ Loaded checkpoint: {latest_checkpoint.name}")
    print(f"  - Resume from index: {start_idx}")
    print(f"  - Embeddings shape: {embeddings.shape}")
    
    return embeddings, start_idx


print("✓ Embedding functions defined")
# Out:
# ✓ Embedding functions defined

# %% [markdown]
# ## 6. Check for Existing Checkpoints (Optional Resume)

# %%
# Check if we should resume from a checkpoint
RESUME_FROM_CHECKPOINT = True  # Set to False to start fresh

if RESUME_FROM_CHECKPOINT:
    existing_embeddings, start_idx = load_latest_checkpoint()
    if existing_embeddings is not None:
        print(f"\n⚠ Found existing checkpoint. Starting from paper {start_idx}")
        print(f"  Change RESUME_FROM_CHECKPOINT to False to start fresh")
    else:
        print("No existing checkpoints found. Starting from beginning.")
        start_idx = 0
else:
    print("Starting fresh (ignoring any existing checkpoints)")
    existing_embeddings = None
    start_idx = 0
# Out:
# No existing checkpoints found. Starting from beginning.

# %% [markdown]
# ## 7. Generate Embeddings (Main Processing)

# %%
# Extract full texts from dataset
print(f"\nExtracting full texts from dataset...")
full_texts = [paper.get('full_text', '') for paper in dataset]

# Count empty texts
empty_count = sum(1 for text in full_texts if not text.strip())
if empty_count > 0:
    print(f"⚠ Warning: Found {empty_count} papers with empty full_text")

# Initialize embeddings list
if existing_embeddings is not None:
    embeddings_list = [existing_embeddings]
else:
    embeddings_list = []

# Calculate total batches
remaining_texts = full_texts[start_idx:]
total_batches = (len(remaining_texts) + BATCH_SIZE - 1) // BATCH_SIZE

print(f"\n{'='*60}")
print(f"Starting embedding generation")
print(f"{'='*60}")
print(f"Total papers: {len(dataset):,}")
print(f"Starting from: {start_idx:,}")
print(f"Remaining: {len(remaining_texts):,}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Total batches: {total_batches:,}")
print(f"{'='*60}\n")

# Process in batches with progress bar
start_time = time.time()
failed_batches = []

try:
    with tqdm(total=len(remaining_texts), desc="Embedding papers", unit="paper") as pbar:
        for i in range(0, len(remaining_texts), BATCH_SIZE):
            batch_texts = remaining_texts[i:i+BATCH_SIZE]
            actual_idx = start_idx + i
            
            try:
                # Generate embeddings for batch
                batch_embeddings = embed_batch(
                    texts=batch_texts,
                    normalize=NORMALIZE,
                    max_length=MAX_LENGTH
                )
                
                embeddings_list.append(batch_embeddings)
                
                # Update progress bar
                pbar.update(len(batch_texts))
                
                # Save checkpoint at intervals
                if (actual_idx + len(batch_texts)) % CHECKPOINT_INTERVAL < BATCH_SIZE:
                    save_checkpoint(embeddings_list, actual_idx + len(batch_texts))
                
            except Exception as e:
                print(f"\n✗ Failed to process batch at index {actual_idx}: {e}")
                failed_batches.append((actual_idx, actual_idx + len(batch_texts)))
                pbar.update(len(batch_texts))
                
except KeyboardInterrupt:
    print("\n\n⚠ Process interrupted by user")
    print("Saving current progress...")
    if embeddings_list:
        save_checkpoint(embeddings_list, start_idx + i)
    raise

# Calculate statistics
elapsed_time = time.time() - start_time
papers_processed = len(remaining_texts) - len(failed_batches) * BATCH_SIZE

print(f"\n{'='*60}")
print(f"Processing complete!")
print(f"{'='*60}")
print(f"Time elapsed: {elapsed_time:.2f}s ({elapsed_time/60:.2f} minutes)")
print(f"Papers processed: {papers_processed:,}")
print(f"Processing rate: {papers_processed/elapsed_time:.2f} papers/second")

if failed_batches:
    print(f"\n⚠ Failed batches: {len(failed_batches)}")
    print(f"  Failed ranges: {failed_batches}")
else:
    print(f"✓ All batches processed successfully!")
# Out:
# Extracting full texts from dataset...
#
# ============================================================
# Starting embedding generation
# ============================================================
# Total papers: 67,043
# Starting from: 0
# Remaining: 67,043
# Batch size: 1
# Total batches: 67,043
# ============================================================
# Embedding papers:   0%|          | 0/67043 [00:00<?, ?paper/s]
# ✗ Failed to process batch at index 499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_500_20251202_224545.npy'
#
# ✗ Failed to process batch at index 999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_1000_20251202_224636.npy'
#
# ✗ Failed to process batch at index 1499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_1500_20251202_224729.npy'
#
# ✗ Failed to process batch at index 1999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_2000_20251202_224820.npy'
#
# ✗ Failed to process batch at index 2499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_2500_20251202_224905.npy'
#
# ✗ Failed to process batch at index 2999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_3000_20251202_224951.npy'
#
# ✗ Failed to process batch at index 3499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_3500_20251202_225036.npy'
#
# ✗ Failed to process batch at index 3999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_4000_20251202_225122.npy'
#
# ✗ Failed to process batch at index 4499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_4500_20251202_225204.npy'
#
# ✗ Failed to process batch at index 4999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_5000_20251202_225250.npy'
#
# ✗ Failed to process batch at index 5499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_5500_20251202_225337.npy'
#
# ✗ Failed to process batch at index 5999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_6000_20251202_225420.npy'
#
# ✗ Failed to process batch at index 6499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_6500_20251202_225507.npy'
#
# ✗ Failed to process batch at index 6999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_7000_20251202_225554.npy'
#
# ✗ Failed to process batch at index 7499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_7500_20251202_225640.npy'
#
# ✗ Failed to process batch at index 7999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_8000_20251202_225723.npy'
#
# ✗ Failed to process batch at index 8499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_8500_20251202_225809.npy'
#
# ✗ Failed to process batch at index 8999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_9000_20251202_225857.npy'
#
# ✗ Failed to process batch at index 9499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_9500_20251202_225943.npy'
#
# ✗ Failed to process batch at index 9999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_10000_20251202_230028.npy'
#
# ✗ Failed to process batch at index 10499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_10500_20251202_230114.npy'
#
# ✗ Failed to process batch at index 10999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_11000_20251202_230201.npy'
#
# ✗ Failed to process batch at index 11499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_11500_20251202_230248.npy'
#
# ✗ Failed to process batch at index 11999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_12000_20251202_230334.npy'
#
# ✗ Failed to process batch at index 12499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_12500_20251202_230420.npy'
#
# ✗ Failed to process batch at index 12999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_13000_20251202_230504.npy'
#
# ✗ Failed to process batch at index 13499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_13500_20251202_230552.npy'
#
# ✗ Failed to process batch at index 13999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_14000_20251202_230639.npy'
#
# ✗ Failed to process batch at index 14499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_14500_20251202_230728.npy'
#
# ✗ Failed to process batch at index 14999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_15000_20251202_230815.npy'
#
# ✗ Failed to process batch at index 15499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_15500_20251202_230902.npy'
#
# ✗ Failed to process batch at index 15999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_16000_20251202_230946.npy'
#
# ✗ Failed to process batch at index 16499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_16500_20251202_231034.npy'
#
# ✗ Failed to process batch at index 16999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_17000_20251202_231120.npy'
#
# ✗ Failed to process batch at index 17499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_17500_20251202_231209.npy'
#
# ✗ Failed to process batch at index 17999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_18000_20251202_231259.npy'
#
# ✗ Failed to process batch at index 18499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_18500_20251202_231346.npy'
#
# ✗ Failed to process batch at index 18999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_19000_20251202_231433.npy'
#
# ✗ Failed to process batch at index 19499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_19500_20251202_231519.npy'
#
# ✗ Failed to process batch at index 19999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_20000_20251202_231607.npy'
#
# ✗ Failed to process batch at index 20499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_20500_20251202_231654.npy'
#
# ✗ Failed to process batch at index 20999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_21000_20251202_231747.npy'
#
# ✗ Failed to process batch at index 21499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_21500_20251202_231838.npy'
#
# ✗ Failed to process batch at index 21999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_22000_20251202_231929.npy'
#
# ✗ Failed to process batch at index 22499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_22500_20251202_232018.npy'
#
# ✗ Failed to process batch at index 22999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_23000_20251202_232105.npy'
#
# ✗ Failed to process batch at index 23499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_23500_20251202_232156.npy'
#
# ✗ Failed to process batch at index 23999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_24000_20251202_232245.npy'
#
# ✗ Failed to process batch at index 24499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_24500_20251202_232333.npy'
#
# ✗ Failed to process batch at index 24999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_25000_20251202_232426.npy'
#
# ✗ Failed to process batch at index 25499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_25500_20251202_232516.npy'
#
# ✗ Failed to process batch at index 25999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_26000_20251202_232607.npy'
#
# ✗ Failed to process batch at index 26499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_26500_20251202_232655.npy'
#
# ✗ Failed to process batch at index 26999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_27000_20251202_232742.npy'
#
# ✗ Failed to process batch at index 27499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_27500_20251202_232833.npy'
#
# ✗ Failed to process batch at index 27999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_28000_20251202_232924.npy'
#
# ✗ Failed to process batch at index 28499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_28500_20251202_233012.npy'
#
# ✗ Failed to process batch at index 28999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_29000_20251202_233104.npy'
#
# ✗ Failed to process batch at index 29499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_29500_20251202_233154.npy'
#
# ✗ Failed to process batch at index 29999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_30000_20251202_233245.npy'
#
# ✗ Failed to process batch at index 30499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_30500_20251202_233335.npy'
#
# ✗ Failed to process batch at index 30999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_31000_20251202_233425.npy'
#
# ✗ Failed to process batch at index 31499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_31500_20251202_233513.npy'
#
# ✗ Failed to process batch at index 31999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_32000_20251202_233602.npy'
#
# ✗ Failed to process batch at index 32499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_32500_20251202_233654.npy'
#
# ✗ Failed to process batch at index 32999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_33000_20251202_233746.npy'
#
# ✗ Failed to process batch at index 33499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_33500_20251202_233836.npy'
#
# ✗ Failed to process batch at index 33999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_34000_20251202_233928.npy'
#
# ✗ Failed to process batch at index 34499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_34500_20251202_234022.npy'
#
# ✗ Failed to process batch at index 34999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_35000_20251202_234113.npy'
#
# ✗ Failed to process batch at index 35499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_35500_20251202_234202.npy'
#
# ✗ Failed to process batch at index 35999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_36000_20251202_234253.npy'
#
# ✗ Failed to process batch at index 36499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_36500_20251202_234343.npy'
#
# ✗ Failed to process batch at index 36999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_37000_20251202_234436.npy'
#
# ✗ Failed to process batch at index 37499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_37500_20251202_234530.npy'
#
# ✗ Failed to process batch at index 37999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_38000_20251202_234622.npy'
#
# ✗ Failed to process batch at index 38499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_38500_20251202_234710.npy'
#
# ✗ Failed to process batch at index 38999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_39000_20251202_234803.npy'
#
# ✗ Failed to process batch at index 39499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_39500_20251202_234856.npy'
#
# ✗ Failed to process batch at index 39999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_40000_20251202_234948.npy'
#
# ✗ Failed to process batch at index 40499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_40500_20251202_235038.npy'
#
# ✗ Failed to process batch at index 40999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_41000_20251202_235129.npy'
#
# ✗ Failed to process batch at index 41499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_41500_20251202_235222.npy'
#
# ✗ Failed to process batch at index 41999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_42000_20251202_235315.npy'
#
# ✗ Failed to process batch at index 42499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_42500_20251202_235409.npy'
#
# ✗ Failed to process batch at index 42999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_43000_20251202_235501.npy'
#
# ✗ Failed to process batch at index 43499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_43500_20251202_235552.npy'
#
# ✗ Failed to process batch at index 43999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_44000_20251202_235646.npy'
#
# ✗ Failed to process batch at index 44499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_44500_20251202_235741.npy'
#
# ✗ Failed to process batch at index 44999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_45000_20251202_235833.npy'
#
# ✗ Failed to process batch at index 45499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_45500_20251202_235927.npy'
#
# ✗ Failed to process batch at index 45999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_46000_20251203_000019.npy'
#
# ✗ Failed to process batch at index 46499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_46500_20251203_000113.npy'
#
# ✗ Failed to process batch at index 46999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_47000_20251203_000207.npy'
#
# ✗ Failed to process batch at index 47499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_47500_20251203_000302.npy'
#
# ✗ Failed to process batch at index 47999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_48000_20251203_000354.npy'
#
# ✗ Failed to process batch at index 48499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_48500_20251203_000447.npy'
#
# ✗ Failed to process batch at index 48999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_49000_20251203_000541.npy'
#
# ✗ Failed to process batch at index 49499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_49500_20251203_000635.npy'
#
# ✗ Failed to process batch at index 49999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_50000_20251203_000725.npy'
#
# ✗ Failed to process batch at index 50499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_50500_20251203_000817.npy'
#
# ✗ Failed to process batch at index 50999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_51000_20251203_000908.npy'
#
# ✗ Failed to process batch at index 51499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_51500_20251203_001002.npy'
#
# ✗ Failed to process batch at index 51999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_52000_20251203_001055.npy'
#
# ✗ Failed to process batch at index 52499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_52500_20251203_001148.npy'
#
# ✗ Failed to process batch at index 52999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_53000_20251203_001240.npy'
#
# ✗ Failed to process batch at index 53499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_53500_20251203_001333.npy'
#
# ✗ Failed to process batch at index 53999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_54000_20251203_001427.npy'
#
# ✗ Failed to process batch at index 54499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_54500_20251203_001519.npy'
#
# ✗ Failed to process batch at index 54999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_55000_20251203_001612.npy'
#
# ✗ Failed to process batch at index 55499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_55500_20251203_001706.npy'
#
# ✗ Failed to process batch at index 55999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_56000_20251203_001757.npy'
#
# ✗ Failed to process batch at index 56499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_56500_20251203_001850.npy'
#
# ✗ Failed to process batch at index 56999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_57000_20251203_001940.npy'
#
# ✗ Failed to process batch at index 57499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_57500_20251203_002032.npy'
#
# ✗ Failed to process batch at index 57999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_58000_20251203_002127.npy'
#
# ✗ Failed to process batch at index 58499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_58500_20251203_002223.npy'
#
# ✗ Failed to process batch at index 58999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_59000_20251203_002318.npy'
#
# ✗ Failed to process batch at index 59499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_59500_20251203_002411.npy'
#
# ✗ Failed to process batch at index 59999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_60000_20251203_002504.npy'
#
# ✗ Failed to process batch at index 60499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_60500_20251203_002559.npy'
#
# ✗ Failed to process batch at index 60999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_61000_20251203_002653.npy'
#
# ✗ Failed to process batch at index 61499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_61500_20251203_002747.npy'
#
# ✗ Failed to process batch at index 61999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_62000_20251203_002841.npy'
#
# ✗ Failed to process batch at index 62499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_62500_20251203_002932.npy'
#
# ✗ Failed to process batch at index 62999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_63000_20251203_003024.npy'
#
# ✗ Failed to process batch at index 63499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_63500_20251203_003114.npy'
#
# ✗ Failed to process batch at index 63999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_64000_20251203_003207.npy'
#
# ✗ Failed to process batch at index 64499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_64500_20251203_003302.npy'
#
# ✗ Failed to process batch at index 64999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_65000_20251203_003357.npy'
#
# ✗ Failed to process batch at index 65499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_65500_20251203_003451.npy'
#
# ✗ Failed to process batch at index 65999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_66000_20251203_003547.npy'
#
# ✗ Failed to process batch at index 66499: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_66500_20251203_003640.npy'
#
# ✗ Failed to process batch at index 66999: [Errno 2] No such file or directory: 'bert_checkpoints\\checkpoint_67000_20251203_003736.npy'
#
# ============================================================
# Processing complete!
# ============================================================
# Time elapsed: 6769.70s (112.83 minutes)
# Papers processed: 66,909
# Processing rate: 9.88 papers/second
#
# ⚠ Failed batches: 134
#   Failed ranges: [(499, 500), (999, 1000), (1499, 1500), (1999, 2000), (2499, 2500), (2999, 3000), (3499, 3500), (3999, 4000), (4499, 4500), (4999, 5000), (5499, 5500), (5999, 6000), (6499, 6500), (6999, 7000), (7499, 7500), (7999, 8000), (8499, 8500), (8999, 9000), (9499, 9500), (9999, 10000), (10499, 10500), (10999, 11000), (11499, 11500), (11999, 12000), (12499, 12500), (12999, 13000), (13499, 13500), (13999, 14000), (14499, 14500), (14999, 15000), (15499, 15500), (15999, 16000), (16499, 16500), (16999, 17000), (17499, 17500), (17999, 18000), (18499, 18500), (18999, 19000), (19499, 19500), (19999, 20000), (20499, 20500), (20999, 21000), (21499, 21500), (21999, 22000), (22499, 22500), (22999, 23000), (23499, 23500), (23999, 24000), (24499, 24500), (24999, 25000), (25499, 25500), (25999, 26000), (26499, 26500), (26999, 27000), (27499, 27500), (27999, 28000), (28499, 28500), (28999, 29000), (29499, 29500), (29999, 30000), (30499, 30500), (30999, 31000), (31499, 31500), (31999, 32000), (32499, 32500), (32999, 33000), (33499, 33500), (33999, 34000), (34499, 34500), (34999, 35000), (35499, 35500), (35999, 36000), (36499, 36500), (36999, 37000), (37499, 37500), (37999, 38000), (38499, 38500), (38999, 39000), (39499, 39500), (39999, 40000), (40499, 40500), (40999, 41000), (41499, 41500), (41999, 42000), (42499, 42500), (42999, 43000), (43499, 43500), (43999, 44000), (44499, 44500), (44999, 45000), (45499, 45500), (45999, 46000), (46499, 46500), (46999, 47000), (47499, 47500), (47999, 48000), (48499, 48500), (48999, 49000), (49499, 49500), (49999, 50000), (50499, 50500), (50999, 51000), (51499, 51500), (51999, 52000), (52499, 52500), (52999, 53000), (53499, 53500), (53999, 54000), (54499, 54500), (54999, 55000), (55499, 55500), (55999, 56000), (56499, 56500), (56999, 57000), (57499, 57500), (57999, 58000), (58499, 58500), (58999, 59000), (59499, 59500), (59999, 60000), (60499, 60500), (60999, 61000), (61499, 61500), (61999, 62000), (62499, 62500), (62999, 63000), (63499, 63500), (63999, 64000), (64499, 64500), (64999, 65000), (65499, 65500), (65999, 66000), (66499, 66500), (66999, 67000)]

# %% [markdown]
# ## 7a. Safety Check - Verify All Embeddings

# %%
# Safety Check: Verify all embeddings exist and are valid
print("Running safety checks on embeddings...\n")

# Check 1: Verify we have embeddings for all papers
expected_count = len(full_texts) if start_idx == 0 else len(full_texts)
actual_count = sum(emb.shape[0] for emb in embeddings_list)

print(f"Check 1: Count verification")
print(f"  - Expected embeddings: {expected_count:,}")
print(f"  - Actual embeddings: {actual_count:,}")

if actual_count == expected_count:
    print(f"  ✓ All papers have embeddings\n")
elif actual_count < expected_count:
    missing = expected_count - actual_count
    print(f"  ⚠ Missing {missing:,} embeddings!\n")
else:
    print(f"  ⚠ More embeddings than papers ({actual_count - expected_count:,} extra)!\n")

# Check 2: Verify embedding dimensions are consistent
print(f"Check 2: Dimension verification")
dimensions = [emb.shape[1] for emb in embeddings_list]
unique_dims = set(dimensions)

if len(unique_dims) == 1:
    print(f"  ✓ All embeddings have dimension: {dimensions[0]}")
    if dimensions[0] == EMBEDDING_DIM:
        print(f"  ✓ Matches expected dimension: {EMBEDDING_DIM}\n")
    else:
        print(f"  ⚠ Expected dimension {EMBEDDING_DIM}, got {dimensions[0]}\n")
else:
    print(f"  ✗ Inconsistent dimensions found: {unique_dims}\n")

# Check 3: Check for NaN or Inf values
print(f"Check 3: Validity check (NaN/Inf)")
has_issues = False
for idx, emb_batch in enumerate(embeddings_list):
    nan_count = np.isnan(emb_batch).sum()
    inf_count = np.isinf(emb_batch).sum()
    
    if nan_count > 0 or inf_count > 0:
        print(f"  ✗ Batch {idx}: {nan_count} NaN values, {inf_count} Inf values")
        has_issues = True

if not has_issues:
    print(f"  ✓ No NaN or Inf values found\n")
else:
    print(f"  ⚠ Invalid values detected!\n")

# Check 4: Verify normalization (if enabled)
if NORMALIZE:
    print(f"Check 4: Normalization verification")
    all_norms_valid = True
    
    for idx, emb_batch in enumerate(embeddings_list):
        norms = np.linalg.norm(emb_batch, axis=1)
        # Check if norms are close to 1.0 (within tolerance)
        if not np.allclose(norms, 1.0, atol=1e-5):
            print(f"  ⚠ Batch {idx}: Norms not normalized (mean: {norms.mean():.6f})")
            all_norms_valid = False
    
    if all_norms_valid:
        print(f"  ✓ All embeddings are properly normalized\n")
    else:
        print(f"  ⚠ Some embeddings are not normalized!\n")

# Check 5: Verify no zero vectors
print(f"Check 5: Zero vector check")
zero_vectors = 0
for emb_batch in embeddings_list:
    # Check if any row is all zeros
    zero_mask = ~emb_batch.any(axis=1)
    zero_vectors += zero_mask.sum()

if zero_vectors == 0:
    print(f"  ✓ No zero vectors found\n")
else:
    print(f"  ⚠ Found {zero_vectors} zero vectors!\n")

# Check 6: Sample embedding range check
print(f"Check 6: Value range check")
all_values = np.concatenate([emb.flatten() for emb in embeddings_list])
print(f"  - Min value: {all_values.min():.6f}")
print(f"  - Max value: {all_values.max():.6f}")
print(f"  - Mean value: {all_values.mean():.6f}")
print(f"  - Std deviation: {all_values.std():.6f}")

if NORMALIZE:
    # For normalized vectors, values should typically be in [-1, 1]
    if all_values.min() >= -1.0 and all_values.max() <= 1.0:
        print(f"  ✓ Values within expected range for normalized embeddings [-1, 1]\n")
    else:
        print(f"  ⚠ Values outside expected range!\n")

# Summary
print(f"{'='*60}")
print(f"Safety Check Summary")
print(f"{'='*60}")

all_checks_passed = (
    actual_count == expected_count and
    len(unique_dims) == 1 and
    not has_issues and
    zero_vectors == 0
)

if all_checks_passed:
    print(f"✓ All safety checks passed! Embeddings are valid.")
else:
    print(f"⚠ Some checks failed. Review the results above.")
    
print(f"{'='*60}\n")
# Out:
# Running safety checks on embeddings...
#
# Check 1: Count verification
#   - Expected embeddings: 67,043
#   - Actual embeddings: 67,043
#   ✓ All papers have embeddings
#
# Check 2: Dimension verification
#   ✓ All embeddings have dimension: 1024
#   ✓ Matches expected dimension: 1024
#
# Check 3: Validity check (NaN/Inf)
#   ✓ No NaN or Inf values found
#
# Check 4: Normalization verification
#   ✓ All embeddings are properly normalized
#
# Check 5: Zero vector check
#   ✓ No zero vectors found
#
# Check 6: Value range check
#   - Min value: -0.987894
#   - Max value: 0.054848
#   - Mean value: -0.000473
#   - Std deviation: 0.031248
#   ✓ Values within expected range for normalized embeddings [-1, 1]
#
# ============================================================
# Safety Check Summary
# ============================================================
# ✓ All safety checks passed! Embeddings are valid.
# ============================================================

# %% [markdown]
# ## 7b. Fill Missing Embeddings (If Any)

# %%
# Identify and compute embeddings for missing papers
print("Checking for missing embeddings...\n")

# Calculate which papers are missing
expected_count = len(full_texts)
actual_count = sum(emb.shape[0] for emb in embeddings_list)

if actual_count < expected_count:
    missing_count = expected_count - actual_count
    print(f"Found {missing_count:,} missing embeddings")
    print(f"Missing papers are at indices: {actual_count} to {expected_count - 1}\n")
    
    # Identify the missing range
    missing_start = actual_count
    missing_end = expected_count
    missing_texts = full_texts[missing_start:missing_end]
    
    print(f"Processing {len(missing_texts):,} missing papers...")
    print(f"{'='*60}\n")
    
    # Process missing papers in batches
    missing_embeddings = []
    missing_failed_batches = []
    
    start_time = time.time()
    
    try:
        with tqdm(total=len(missing_texts), desc="Computing missing embeddings", unit="paper") as pbar:
            for i in range(0, len(missing_texts), BATCH_SIZE):
                batch_texts = missing_texts[i:i+BATCH_SIZE]
                actual_idx = missing_start + i
                
                try:
                    # Generate embeddings for batch
                    batch_embeddings = embed_batch(
                        texts=batch_texts,
                        normalize=NORMALIZE,
                        max_length=MAX_LENGTH
                    )
                    
                    missing_embeddings.append(batch_embeddings)
                    
                    # Update progress bar
                    pbar.update(len(batch_texts))
                    
                except Exception as e:
                    print(f"\n✗ Failed to process batch at index {actual_idx}: {e}")
                    missing_failed_batches.append((actual_idx, actual_idx + len(batch_texts)))
                    pbar.update(len(batch_texts))
                    
    except KeyboardInterrupt:
        print("\n\n⚠ Process interrupted by user")
        print("Partial progress on missing embeddings saved in memory")
        raise
    
    elapsed_time = time.time() - start_time
    
    if missing_embeddings:
        # Add the missing embeddings to the main list
        embeddings_list.extend(missing_embeddings)
        
        print(f"\n✓ Completed processing missing embeddings")
        print(f"  - Time: {elapsed_time:.2f}s")
        print(f"  - Processed: {sum(e.shape[0] for e in missing_embeddings):,} embeddings")
        
        if missing_failed_batches:
            print(f"  - Failed batches: {len(missing_failed_batches)}")
            print(f"  - Failed ranges: {missing_failed_batches}")
        
        # Save a checkpoint with the complete data
        print(f"\n  Saving checkpoint with complete data...")
        save_checkpoint(embeddings_list, expected_count)
        
        # Re-verify count
        new_count = sum(emb.shape[0] for emb in embeddings_list)
        print(f"\n  New total embeddings: {new_count:,}")
        if new_count == expected_count:
            print(f"  ✓ All missing embeddings filled successfully!\n")
        else:
            still_missing = expected_count - new_count
            print(f"  ⚠ Still missing {still_missing:,} embeddings\n")
    else:
        print(f"\n✗ No embeddings were computed for missing papers")
        print(f"  Check the error messages above\n")
        
elif actual_count > expected_count:
    print(f"⚠ Warning: More embeddings ({actual_count:,}) than papers ({expected_count:,})")
    print(f"  Extra embeddings will be truncated when combining.\n")
    
else:
    print(f"✓ No missing embeddings - all {expected_count:,} papers have embeddings!\n")
# Out:
# Checking for missing embeddings...
#
# ✓ No missing embeddings - all 67,043 papers have embeddings!

# %% [markdown]
# ## 8. Combine and Save Embeddings

# %%
# Combine all embeddings into a single array
print("\nCombining embeddings...")
all_embeddings = np.vstack(embeddings_list)

print(f"✓ Final embeddings shape: {all_embeddings.shape}")
print(f"  - Number of papers: {all_embeddings.shape[0]:,}")
print(f"  - Embedding dimension: {all_embeddings.shape[1]}")
print(f"  - Data type: {all_embeddings.dtype}")
print(f"  - Memory size: {all_embeddings.nbytes / (1024**2):.2f} MB")

# Verify embeddings
print(f"\nEmbedding statistics:")
print(f"  - Min value: {all_embeddings.min():.6f}")
print(f"  - Max value: {all_embeddings.max():.6f}")
print(f"  - Mean value: {all_embeddings.mean():.6f}")
print(f"  - Std deviation: {all_embeddings.std():.6f}")

if NORMALIZE:
    # Check normalization (should be close to 1.0)
    norms = np.linalg.norm(all_embeddings, axis=1)
    print(f"\nNormalization check (should be ~1.0):")
    print(f"  - Mean L2 norm: {norms.mean():.6f}")
    print(f"  - Min L2 norm: {norms.min():.6f}")
    print(f"  - Max L2 norm: {norms.max():.6f}")
# Out:
# Combining embeddings...
# ✓ Final embeddings shape: (67043, 1024)
#   - Number of papers: 67,043
#   - Embedding dimension: 1024
#   - Data type: float32
#   - Memory size: 261.89 MB
#
# Embedding statistics:
#   - Min value: -0.987894
#   - Max value: 0.054848
#   - Mean value: -0.000473
#   - Std deviation: 0.031248
#
# Normalization check (should be ~1.0):
#   - Mean L2 norm: 1.000000
#   - Min L2 norm: 1.000000
#   - Max L2 norm: 1.000000

# %%
# Save embeddings to file
print(f"\nSaving embeddings to {OUTPUT_EMBEDDINGS}...")
np.save(OUTPUT_EMBEDDINGS, all_embeddings)
file_size = os.path.getsize(OUTPUT_EMBEDDINGS) / (1024**2)
print(f"✓ Embeddings saved successfully ({file_size:.2f} MB)")

# Create metadata
metadata = {
    "created_at": datetime.now().isoformat(),
    "model": "thomas-sounack/BioClinical-ModernBERT-large",
    "api_url": BERT_API_URL,
    "embedding_dimension": int(all_embeddings.shape[1]),
    "num_papers": int(all_embeddings.shape[0]),
    "input_file": INPUT_FILE,
    "output_file": OUTPUT_EMBEDDINGS,
    "normalized": NORMALIZE,
    "max_length": MAX_LENGTH,
    "batch_size": BATCH_SIZE,
    "processing_time_seconds": elapsed_time,
    "processing_rate_papers_per_second": papers_processed / elapsed_time,
    "failed_batches": failed_batches,
    "dtype": str(all_embeddings.dtype),
    "file_size_mb": file_size,
    "statistics": {
        "min": float(all_embeddings.min()),
        "max": float(all_embeddings.max()),
        "mean": float(all_embeddings.mean()),
        "std": float(all_embeddings.std())
    }
}

# Save metadata
print(f"Saving metadata to {OUTPUT_METADATA}...")
with open(OUTPUT_METADATA, 'w', encoding='utf-8') as f:
    json.dump(metadata, f, indent=2)

print(f"✓ Metadata saved successfully")

print(f"\n{'='*60}")
print(f"✓ ALL DONE!")
print(f"{'='*60}")
print(f"\nOutput files:")
print(f"  1. {OUTPUT_EMBEDDINGS} - NumPy array of embeddings")
print(f"  2. {OUTPUT_METADATA} - Metadata JSON file")
print(f"\nTo load embeddings later:")
print(f"  embeddings = np.load('{OUTPUT_EMBEDDINGS}')")
# Out:
# Saving embeddings to bert_embeddings.npy...
# ✓ Embeddings saved successfully (261.89 MB)
# Saving metadata to bert_embeddings_metadata.json...
# ✓ Metadata saved successfully
#
# ============================================================
# ✓ ALL DONE!
# ============================================================
#
# Output files:
#   1. bert_embeddings.npy - NumPy array of embeddings
#   2. bert_embeddings_metadata.json - Metadata JSON file
#
# To load embeddings later:
#   embeddings = np.load('bert_embeddings.npy')

# %% [markdown]
# ## 9. Quick Verification & Example Usage

# %%
# Load the saved embeddings to verify
print("Verifying saved embeddings...")
loaded_embeddings = np.load(OUTPUT_EMBEDDINGS)

print(f"✓ Successfully loaded embeddings")
print(f"  - Shape: {loaded_embeddings.shape}")
print(f"  - Data type: {loaded_embeddings.dtype}")

# Verify they match
if np.allclose(loaded_embeddings, all_embeddings):
    print(f"✓ Loaded embeddings match the generated embeddings!")
else:
    print(f"⚠ Warning: Loaded embeddings differ from generated embeddings")
# Out:
# Verifying saved embeddings...
# ✓ Successfully loaded embeddings
#   - Shape: (67043, 1024)
#   - Data type: float32
# ✓ Loaded embeddings match the generated embeddings!

# %%
# Example: Compute similarity between two random papers
print("\nExample: Computing similarity between papers...\n")

# Select two random papers
idx1, idx2 = 0, 100  # You can change these indices

# Get their embeddings
emb1 = loaded_embeddings[idx1]
emb2 = loaded_embeddings[idx2]

# Compute cosine similarity (dot product since they're normalized)
similarity = np.dot(emb1, emb2)

print(f"Paper {idx1}:")
if 'title' in dataset[idx1]:
    print(f"  Title: {dataset[idx1]['title'][:100]}...")
print(f"  Text preview: {full_texts[idx1][:150]}...\n")

print(f"Paper {idx2}:")
if 'title' in dataset[idx2]:
    print(f"  Title: {dataset[idx2]['title'][:100]}...")
print(f"  Text preview: {full_texts[idx2][:150]}...\n")

print(f"Cosine similarity: {similarity:.4f}")
print(f"(Range: -1 to 1, where 1 = identical, 0 = orthogonal, -1 = opposite)")
# Out:
# Example: Computing similarity between papers...
#
# Paper 0:
#   Title: Immunomodulation by cytokine antisense oligonucleotides....
#   Text preview: Immunomodulation by cytokine antisense oligonucleotides. The cytokine network is involved in normal immune reaction and in the progression of several ...
#
# Paper 100:
#   Title: Formulation and biological activity of antineoplastic proteoglycans derived from Mycobacterium vacca...
#   Text preview: Formulation and biological activity of antineoplastic proteoglycans derived from Mycobacterium vaccae in chitosan nanoparticles. Although heat-killed ...
#
# Cosine similarity: 0.9948
# (Range: -1 to 1, where 1 = identical, 0 = orthogonal, -1 = opposite)

# %%
# Example: Find most similar papers to a given paper
print("\nExample: Finding most similar papers...\n")

query_idx = 0  # Change this to any paper index
top_k = 5  # Number of similar papers to find

# Get query embedding
query_emb = loaded_embeddings[query_idx]

# Compute similarities with all papers
similarities = np.dot(loaded_embeddings, query_emb)

# Get top-k most similar (excluding the query itself)
top_indices = np.argsort(similarities)[::-1][1:top_k+1]  # Skip first (itself)

print(f"Query paper (index {query_idx}):")
if 'title' in dataset[query_idx]:
    print(f"  Title: {dataset[query_idx]['title']}")
print(f"  Text preview: {full_texts[query_idx][:200]}...\n")

print(f"Top {top_k} most similar papers:\n")
for rank, idx in enumerate(top_indices, 1):
    print(f"{rank}. Paper {idx} (similarity: {similarities[idx]:.4f})")
    if 'title' in dataset[idx]:
        print(f"   Title: {dataset[idx]['title']}")
    print(f"   Text preview: {full_texts[idx][:150]}...")
    print()
# Out:
# Example: Finding most similar papers...
#
# Query paper (index 0):
#   Title: Immunomodulation by cytokine antisense oligonucleotides.
#   Text preview: Immunomodulation by cytokine antisense oligonucleotides. The cytokine network is involved in normal immune reaction and in the progression of several pathologies. Antisense (AS) oligonucleotides, whic...
#
# Top 5 most similar papers:
#
# 1. Paper 16350 (similarity: 0.9973)
#    Title: Nanocomplexes for gene therapy of respiratory diseases: Targeting and overcoming the mucus barrier.
#    Text preview: Nanocomplexes for gene therapy of respiratory diseases: Targeting and overcoming the mucus barrier. Gene therapy, i.e. the delivery and expression of ...
#
# 2. Paper 31 (similarity: 0.9968)
#    Title: A new family of carriers (biovectors) enhances the immunogenicity of rabies antigens.
#    Text preview: A new family of carriers (biovectors) enhances the immunogenicity of rabies antigens. Biovectors (BV) are a new family of protein carriers. They are n...
#
# 3. Paper 43457 (similarity: 0.9968)
#    Title: Encapsulation and release of As pidasept peptides in polysaccharide formulation for oral application.
#    Text preview: Encapsulation and release of As pidasept peptides in polysaccharide formulation for oral application. Due to the increase in bacterial resistance to c...
#
# 4. Paper 19355 (similarity: 0.9967)
#    Title: Immunomodulation of hematological malignancies using oligonucleotides based-nanomedicines.
#    Text preview: Immunomodulation of hematological malignancies using oligonucleotides based-nanomedicines. Hematological malignancies are a group of diseases characte...
#
# 5. Paper 3071 (similarity: 0.9966)
#    Title: Polyalkylcyanoacrylate nanoparticles for delivery of drugs across the blood-brain barrier.
#    Text preview: Polyalkylcyanoacrylate nanoparticles for delivery of drugs across the blood-brain barrier. The major problem in drug delivery to the brain is the pres...

# %% [markdown]
# ## 10. Clean Up Checkpoints (Optional)

# %%
# Optionally remove checkpoint files after successful completion
REMOVE_CHECKPOINTS = False  # Set to True to remove checkpoints

if REMOVE_CHECKPOINTS:
    checkpoint_files = list(Path(CHECKPOINT_DIR).glob("checkpoint_*.npy"))
    if checkpoint_files:
        print(f"Removing {len(checkpoint_files)} checkpoint files...")
        for checkpoint_file in checkpoint_files:
            checkpoint_file.unlink()
            print(f"  Removed: {checkpoint_file.name}")
        print(f"✓ Checkpoints cleaned up")
    else:
        print("No checkpoint files to remove")
else:
    print("Keeping checkpoint files (set REMOVE_CHECKPOINTS=True to remove)")
    checkpoint_files = list(Path(CHECKPOINT_DIR).glob("checkpoint_*.npy"))
    if checkpoint_files:
        print(f"  Found {len(checkpoint_files)} checkpoint files in {CHECKPOINT_DIR}/")
