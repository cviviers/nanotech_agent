# %%
from openai import OpenAI
import os
import numpy as np
import pandas as pd

# Set the API key
api_key = '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'
# Create the OpenAI object

client = OpenAI(api_key = api_key)

# %%
def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding
